# %%
# !mongo open_food --quiet --eval 'db.products.count()'
# Out:
# 309370

# %%
# %env selection = {"categories":"Snacks, Sweet snacks, Confectioneries, Candies, Chews"}
# %env projection = {"_id": 1, "product_name": 1}
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection})"
# Out:
# env: selection={"categories":"Snacks, Sweet snacks, Confectioneries, Candies, Chews"}
# env: projection={"_id": 1, "product_name": 1}
# { "_id" : "0071720007105", "product_name" : "Tootsie Roll" }

# %%
# %env selection = {"last_modified_t": {$gte: 1601856000}}
# %env projection = {"_id": 1, "code": 1, "product_name": 1}
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection})"
# Out:
# env: selection={"last_modified_t": {$gte: 1601856000}}
# env: projection={"_id": 1, "code": 1, "product_name": 1}
# { "_id" : "0852909003299", "product_name" : "Almondmilk", "code" : "0852909003299" }
# { "_id" : "0840423102055", "code" : "0840423102055", "product_name" : "Garlic wine pasta with chicken meatballs with whole wheat rotini, white beans, and greens, cooked in avocado oil, and topped with parmesan and mozzarella, garlic wine pasta with chicken meatballs" }

# %%
# !mongo open_food --quiet --eval 'db.products.count({"packaging": "Plastic"})'
# Out:
# 115

# %%
# %env selection = {"manufacturing_places":"Austin, TX", "stores": "Whole Foods"}
# %env projection = {"_id": 1, "code": 1, "creator": 1, "product_name": 1, "brands":1}
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection})"
# Out:
# env: selection={"manufacturing_places":"Austin, TX", "stores": "Whole Foods"}
# env: projection={"_id": 1, "code": 1, "creator": 1, "product_name": 1, "brands":1}
# { "_id" : "0099482455859", "creator" : "usda-ndb-import", "brands" : "365 Everyday Value,Whole Foods Market  Inc.", "code" : "0099482455859", "product_name" : "Whole Wheat Bread" }

# %%
# !mongo open_food --quiet --eval 'db.products.find({brands: {$in: ["m&m\u0027s", "mars", "Mars", "oreo", "starburst"]}}, {_id:1, product_name:1, brands:1}).sort({product_name: 1}).limit(5)'
# Out:
# { "_id" : "0040000265252", "brands" : "Mars", "product_name" : "Almond & dark chocolate" }
# { "_id" : "0040000422068", "brands" : "mars", "product_name" : "BAR" }
# { "_id" : "0047677386518", "brands" : "m&m's", "product_name" : "M&m's, light ice cream, chocolate" }
# { "_id" : "0044000029524", "product_name" : "Nabisco oreo cookies double stuf 1x4.1 oz", "brands" : "oreo" }
# { "_id" : "04005108", "product_name" : "Real fruit juice!", "brands" : "starburst" }

# %%
# select _id, product_name, countries, ingredients.text,
# ingredients.rank, nutriments.carbohydrates_serving
# from products
# where nutriments.carbohydrates_serving between 18 and 25
# order by ingredients.rank DESC
# limit 5;

# %env selection = {"nutriments.carbohydrates_serving": {$gte: 18}, "nutriments.carbohydrates_serving": {$lte: 25}}
# %env projection = {"_id":1, "product_name":1, "countries":1, "ingredients.text":1, "ingredients.rank": 1, "nutrients.carbohydrates_serving":1}
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection}).sort({'ingredients.rank': -1}).limit(5).pretty()"
# Out:
# env: selection={"nutriments.carbohydrates_serving": {$gte: 18}, "nutriments.carbohydrates_serving": {$lte: 25}}
# env: projection={"_id":1, "product_name":1, "countries":1, "ingredients.text":1, "ingredients.rank": 1, "nutrients.carbohydrates_serving":1}
# {
# 	"_id" : "0686700056815",
# 	"product_name" : "Gamesa Lonchera Assorted Cookies 14.3 Ounce 5 Pack Box",
# 	"countries" : "United States",
# 	"ingredients" : [
# 		{
# 			"text" : "Arcoiris",
# 			"rank" : 1
# 		},
# 		{
# 			"rank" : 2,
# 			"text" : "Niacinamide"
# 		},
# 		{
# 			"text" : "Ferrous Fumarate",
# 			"rank" : 3
# 		},
# 		{
# 			"text" : "Thiamin Mononitrate",
# 			"rank" : 4
# 		},
# 		{
# 			"text" : "Riboflavin",
# 			"rank" : 5
# 		},
# 		{
# 			"text" : "Folic Acid",
# 			"rank" : 6
# 		},
# 		{
# 			"rank" : 7,
# 			"text" : "Sugar"
# 		},
# 		{
# 			"text" : "High Fructose Corn Syrup",
# 			"rank" : 8
# 		},
# 		{
# 			"text" : "Corn Syrup",
# 			"rank" : 9
# 		},
# 		{
# 			"rank" : 10,
# ...

# %%
# %env doc2 = {"ingredients":[{"rank":1,"text":"pork belly"},{"text":"vinegar","rank":2},{"text":"soya","rank":3},{"rank":4,"text":"black peppercorn"}],"countries":"Phillipines","product_name":"Pork Adobo", "stores": "HMart", "packaging": "Plastic"}
# !mongo open_food --quiet --eval "db.products.insertOne(${doc2})"
# Out:
# env: doc2={"ingredients":[{"rank":1,"text":"pork belly"},{"text":"vinegar","rank":2},{"text":"soya","rank":3},{"rank":4,"text":"black peppercorn"}],"countries":"Phillipines","product_name":"Pork Adobo", "stores": "HMart", "packaging": "Plastic"}
# {
# 	"acknowledged" : true,
# 	"insertedId" : ObjectId("624f5581e346479253746e8f")
# }

# %%
#update
# !mongo open_food --quiet --eval 'db.products.updateOne({_id:ObjectId("624f5581e346479253746e8f")}, {$set: {"stores": "99 Ranch"}})'
# Out:
# { "acknowledged" : true, "matchedCount" : 1, "modifiedCount" : 1 }

# %%
#verify update
# !mongo open_food --quiet --eval 'db.products.find({_id:ObjectId("624f5581e346479253746e8f")})'
# Out:
# { "_id" : ObjectId("624f5581e346479253746e8f"), "ingredients" : [ { "rank" : 1, "text" : "pork belly" }, { "text" : "vinegar", "rank" : 2 }, { "text" : "soya", "rank" : 3 }, { "rank" : 4, "text" : "black peppercorn" } ], "countries" : "Phillipines", "product_name" : "Pork Adobo", "stores" : "99 Ranch", "packaging" : "Plastic" }

# %%
# !mongo open_food --quiet --eval 'db.products.deleteOne({_id:ObjectId("624f5581e346479253746e8f")})'
# Out:
# { "acknowledged" : true, "deletedCount" : 1 }

# %%
#verify delete
# !mongo open_food --quiet --eval 'db.products.find({_id:ObjectId("624f5581e346479253746e8f")})'
